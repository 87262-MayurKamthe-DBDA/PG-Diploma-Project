# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("final_1.csv")

# %%
df
# Out:
#        Unnamed: 0  level_0  index  distance cab_type     time_stamp  \
# 0               0        0      0      0.44     Lyft  1544952607890
# 1               1     1353   1353      1.33     Lyft  1544952309308
# 2               2     1460   1460      0.53     Lyft  1544951109578
# 3               3     2888   2888      2.36     Lyft  1544954108860
# 4               4     6749    660      2.39     Lyft  1544951411890
# ...           ...      ...    ...       ...      ...            ...
# 57626       57626    55918  11375      2.67     Lyft  1543210587212
# 57627       57627    55919  11376      2.67     Lyft  1543210587212
# 57628       57628    55920  11377      2.67     Lyft  1543210587212
# 57629       57629    55921  11378      2.67     Lyft  1543210587212
# 57630       57630    56909  12366      0.90     Lyft  1544407118996
#
#                              destination             source  price  \
# 0         North+Station,+Boston,+MA,+USA   Haymarket Square    5.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57631 entries, 0 to 57630
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        57631 non-null  int64
#  1   level_0           57631 non-null  int64
#  2   index             57631 non-null  int64
#  3   distance          57631 non-null  float64
#  4   cab_type          57631 non-null  object
#  5   time_stamp        57631 non-null  int64
#  6   destination       57631 non-null  object
#  7   source            57631 non-null  object
#  8   price             57631 non-null  float64
#  9   surge_multiplier  57631 non-null  float64
#  10  id                57631 non-null  object
#  11  product_id        57631 non-null  object
#  12  name              57631 non-null  object
#  13  date_time         57631 non-null  object
#  14  date              57631 non-null  object
#  15  day               57631 non-null  int64
# ...

# %%
df["cab_type"].unique()
# Out:
# array(['Lyft', 'Uber'], dtype=object)

# %%
sns.set(rc={'figure.figsize':(20,20)})

# %% [markdown]
# ## split the data set into uber and lyft

# %%
df_uber = df[df['cab_type'] == "Uber"]

# %%
df_uber.drop(["level_0"] , axis=1 , inplace=True)
df_uber.reset_index(inplace=True)
df_uber.drop(["level_0"] , axis=1 , inplace=True)
# Out:
# C:\Users\Mayur\AppData\Local\Temp\ipykernel_12784\1649152311.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uber.drop(["level_0"] , axis=1 , inplace=True)
# C:\Users\Mayur\AppData\Local\Temp\ipykernel_12784\1649152311.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uber.drop(["level_0"] , axis=1 , inplace=True)

# %%
df_uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29525 entries, 0 to 29524
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        29525 non-null  int64
#  1   index             29525 non-null  int64
#  2   distance          29525 non-null  float64
#  3   cab_type          29525 non-null  object
#  4   time_stamp        29525 non-null  int64
#  5   destination       29525 non-null  object
#  6   source            29525 non-null  object
#  7   price             29525 non-null  float64
#  8   surge_multiplier  29525 non-null  float64
#  9   id                29525 non-null  object
#  10  product_id        29525 non-null  object
#  11  name              29525 non-null  object
#  12  date_time         29525 non-null  object
#  13  date              29525 non-null  object
#  14  day               29525 non-null  int64
#  15  hour              29525 non-null  int64
# ...

# %%
df_lyft = df[df['cab_type'] == "Lyft"]

# %%
df_lyft.drop(["level_0"] , axis=1 , inplace=True)
df_lyft.reset_index(inplace=True)
df_lyft.drop(["level_0"] , axis=1 , inplace=True)
# Out:
# /var/folders/cz/5p31_18j3kj6h91t_x5gw0k40000gn/T/ipykernel_14133/3652798377.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lyft.drop(["level_0"] , axis=1 , inplace=True)
# /var/folders/cz/5p31_18j3kj6h91t_x5gw0k40000gn/T/ipykernel_14133/3652798377.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lyft.drop(["level_0"] , axis=1 , inplace=True)

# %%
df_lyft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28106 entries, 0 to 28105
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        28106 non-null  int64
#  1   index             28106 non-null  int64
#  2   distance          28106 non-null  float64
#  3   cab_type          28106 non-null  object
#  4   time_stamp        28106 non-null  int64
#  5   destination       28106 non-null  object
#  6   source            28106 non-null  object
#  7   price             28106 non-null  float64
#  8   surge_multiplier  28106 non-null  float64
#  9   id                28106 non-null  object
#  10  product_id        28106 non-null  object
#  11  name              28106 non-null  object
#  12  date_time         28106 non-null  object
#  13  date              28106 non-null  object
#  14  day               28106 non-null  int64
#  15  hour              28106 non-null  int64
# ...

# %% [markdown]
# ## count for every one

# %%
df_uber['destination'].value_counts()
# Out:
# destination
# Boston+University,+Boston,+MA,+USA          2625
# Financial+District,+Boston,+MA,+USA         2613
# Back+Bay,+Boston,+MA,+USA                   2587
# West+End,+Boston,+MA,+USA                   2510
# Haymarket+Square,+Boston,+MA,+USA           2447
# Fenway,+Boston,+MA,+USA                     2429
# South+Station,+Boston,+MA,+USA              2424
# Theatre+District,+Boston,+MA,+USA           2412
# North+End,+Boston,+MA,+USA                  2408
# North+Station,+Boston,+MA,+USA              2388
# Northeastern+University,+Boston,+MA,+USA    2377
# Beacon+Hill,+Boston,+MA,+USA                2305
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_uber , y= "destination")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '2412'),
#  Text(0, 0, '2305'),
#  Text(0, 0, '2388'),
#  Text(0, 0, '2510'),
#  Text(0, 0, '2613'),
#  Text(0, 0, '2587'),
#  Text(0, 0, '2408'),
#  Text(0, 0, '2424'),
#  Text(0, 0, '2625'),
#  Text(0, 0, '2377'),
#  Text(0, 0, '2447'),
#  Text(0, 0, '2429')]

# %%
df_uber['source'].value_counts()
# Out:
# source
# South Station              2598
# Northeastern University    2548
# North End                  2536
# Theatre District           2504
# West End                   2496
# Back Bay                   2477
# Beacon Hill                2452
# North Station              2419
# Fenway                     2402
# Boston University          2389
# Financial District         2362
# Haymarket Square           2342
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_uber , y= "source")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '2342'),
#  Text(0, 0, '2477'),
#  Text(0, 0, '2536'),
#  Text(0, 0, '2419'),
#  Text(0, 0, '2452'),
#  Text(0, 0, '2389'),
#  Text(0, 0, '2402'),
#  Text(0, 0, '2598'),
#  Text(0, 0, '2504'),
#  Text(0, 0, '2496'),
#  Text(0, 0, '2362'),
#  Text(0, 0, '2548')]

# %%
df_lyft['destination'].value_counts()
# Out:
# destination
# Northeastern+University,+Boston,+MA,+USA    2543
# Fenway,+Boston,+MA,+USA                     2422
# South+Station,+Boston,+MA,+USA              2409
# Financial+District,+Boston,+MA,+USA         2381
# North+End,+Boston,+MA,+USA                  2380
# Haymarket+Square,+Boston,+MA,+USA           2360
# Boston+University,+Boston,+MA,+USA          2360
# Beacon+Hill,+Boston,+MA,+USA                2345
# Theatre+District,+Boston,+MA,+USA           2278
# North+Station,+Boston,+MA,+USA              2263
# West+End,+Boston,+MA,+USA                   2192
# Back+Bay,+Boston,+MA,+USA                   2173
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_lyft , y= "destination")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '2263'),
#  Text(0, 0, '2345'),
#  Text(0, 0, '2173'),
#  Text(0, 0, '2381'),
#  Text(0, 0, '2278'),
#  Text(0, 0, '2543'),
#  Text(0, 0, '2422'),
#  Text(0, 0, '2380'),
#  Text(0, 0, '2409'),
#  Text(0, 0, '2360'),
#  Text(0, 0, '2360'),
#  Text(0, 0, '2192')]

# %%
df_lyft['source'].value_counts()
# Out:
# source
# Back Bay                   2650
# West End                   2441
# Beacon Hill                2402
# Financial District         2383
# Boston University          2365
# Fenway                     2364
# Theatre District           2317
# Haymarket Square           2314
# Northeastern University    2289
# North Station              2281
# North End                  2156
# South Station              2144
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_lyft , y= "source")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '2314'),
#  Text(0, 0, '2650'),
#  Text(0, 0, '2156'),
#  Text(0, 0, '2281'),
#  Text(0, 0, '2402'),
#  Text(0, 0, '2365'),
#  Text(0, 0, '2364'),
#  Text(0, 0, '2144'),
#  Text(0, 0, '2317'),
#  Text(0, 0, '2441'),
#  Text(0, 0, '2383'),
#  Text(0, 0, '2289')]

# %%
df_lyft.name.value_counts()
# Out:
# name
# Shared          4701
# Lux Black XL    4691
# Lyft            4687
# Lux             4680
# Lux Black       4677
# Lyft XL         4670
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_lyft , y= "name")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '4701'),
#  Text(0, 0, '4687'),
#  Text(0, 0, '4691'),
#  Text(0, 0, '4680'),
#  Text(0, 0, '4677'),
#  Text(0, 0, '4670')]

# %%
df_uber.name.value_counts()
# Out:
# name
# UberPool     4942
# WAV          4927
# Black SUV    4921
# Black        4919
# UberXL       4913
# UberX        4903
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_uber , y= "name")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '4921'),
#  Text(0, 0, '4919'),
#  Text(0, 0, '4913'),
#  Text(0, 0, '4942'),
#  Text(0, 0, '4903'),
#  Text(0, 0, '4927')]

# %%
df_lyft.product_id.value_counts()
# Out:
# product_id
# lyft_line       4701
# lyft_luxsuv     4691
# lyft            4687
# lyft_premier    4680
# lyft_lux        4677
# lyft_plus       4670
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_lyft , y= "product_id")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '4701'),
#  Text(0, 0, '4687'),
#  Text(0, 0, '4691'),
#  Text(0, 0, '4680'),
#  Text(0, 0, '4677'),
#  Text(0, 0, '4670')]

# %%
df_uber.product_id.value_counts()
# Out:
# product_id
# 997acbb5-e102-41e1-b155-9df7de0a73f2    4942
# 9a0e7b09-b92b-4c41-9779-2ad22b4d779d    4927
# 6d318bcc-22a3-4af6-bddd-b409bfce1546    4921
# 6c84fd89-3f11-4782-9b50-97c468b19529    4919
# 6f72dfc5-27f1-42e8-84db-ccc7a75f6969    4913
# 55c66225-fbe7-4fd5-9072-eab1ece5e23e    4903
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_uber , y= "product_id")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '4921'),
#  Text(0, 0, '4919'),
#  Text(0, 0, '4913'),
#  Text(0, 0, '4942'),
#  Text(0, 0, '4903'),
#  Text(0, 0, '4927')]

# %%
df_uber.surge_multiplier.value_counts()
# Out:
# surge_multiplier
# 1.0    29525
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_uber , x= "surge_multiplier")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '29525')]

# %%
df_lyft.surge_multiplier.value_counts()
# Out:
# surge_multiplier
# 1.00    26211
# 1.25     1008
# 1.50      460
# 2.00      221
# 1.75      188
# 2.50       14
# 3.00        4
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_lyft , x= "surge_multiplier")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '26211'),
#  Text(0, 0, '1008'),
#  Text(0, 0, '460'),
#  Text(0, 0, '188'),
#  Text(0, 0, '221'),
#  Text(0, 0, '14'),
#  Text(0, 0, '4')]

# %%
df_uber.class_hour.value_counts()
# Out:
# class_hour
# 5    4118
# 4    3855
# 7    3777
# 0    3759
# 1    3604
# 6    3604
# 3    3590
# 2    3218
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_uber , x= "class_hour")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '3759'),
#  Text(0, 0, '3604'),
#  Text(0, 0, '3218'),
#  Text(0, 0, '3590'),
#  Text(0, 0, '3855'),
#  Text(0, 0, '4118'),
#  Text(0, 0, '3604'),
#  Text(0, 0, '3777')]

# %%
df_lyft.class_hour.value_counts()
# Out:
# class_hour
# 5    3824
# 4    3757
# 7    3680
# 3    3617
# 0    3479
# 6    3387
# 1    3261
# 2    3101
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_lyft , x= "class_hour")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '3479'),
#  Text(0, 0, '3261'),
#  Text(0, 0, '3101'),
#  Text(0, 0, '3617'),
#  Text(0, 0, '3757'),
#  Text(0, 0, '3824'),
#  Text(0, 0, '3387'),
#  Text(0, 0, '3680')]

# %%
df_uber.hour.value_counts()
# Out:
# hour
# 16    1506
# 23    1374
# 4     1367
# 12    1331
# 15    1329
# 0     1328
# 18    1296
# 13    1290
# 10    1286
# 17    1283
# 2     1279
# 14    1234
# 3     1228
# 11    1220
# 22    1219
# 20    1188
# 21    1184
# 1     1152
# 19    1120
# 6     1092
# 9     1084
# 7     1083
# 8     1043
# 5     1009
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_uber , x= "hour")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '1328'),
#  Text(0, 0, '1152'),
#  Text(0, 0, '1279'),
#  Text(0, 0, '1228'),
#  Text(0, 0, '1367'),
#  Text(0, 0, '1009'),
#  Text(0, 0, '1092'),
#  Text(0, 0, '1083'),
#  Text(0, 0, '1043'),
#  Text(0, 0, '1084'),
#  Text(0, 0, '1286'),
#  Text(0, 0, '1220'),
#  Text(0, 0, '1331'),
#  Text(0, 0, '1290'),
#  Text(0, 0, '1234'),
#  Text(0, 0, '1329'),
#  Text(0, 0, '1506'),
#  Text(0, 0, '1283'),
#  Text(0, 0, '1296'),
#  Text(0, 0, '1120'),
#  Text(0, 0, '1188'),
#  Text(0, 0, '1184'),
#  Text(0, 0, '1219'),
#  Text(0, 0, '1374')]

# %%
df_lyft.hour.value_counts()
# Out:
# hour
# 16    1402
# 14    1297
# 23    1287
# 0     1260
# 18    1253
# 13    1248
# 17    1235
# 11    1232
# 10    1231
# 22    1231
# 12    1212
# 2     1200
# 15    1187
# 21    1162
# 4     1162
# 9     1154
# 6     1138
# 20    1093
# 3     1060
# 19    1041
# 5     1039
# 8     1024
# 1     1019
# 7      939
# Name: count, dtype: int64

# %%
ax =sns.countplot(data=df_lyft , x= "hour")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '1260'),
#  Text(0, 0, '1019'),
#  Text(0, 0, '1200'),
#  Text(0, 0, '1060'),
#  Text(0, 0, '1162'),
#  Text(0, 0, '1039'),
#  Text(0, 0, '1138'),
#  Text(0, 0, '939'),
#  Text(0, 0, '1024'),
#  Text(0, 0, '1154'),
#  Text(0, 0, '1231'),
#  Text(0, 0, '1232'),
#  Text(0, 0, '1212'),
#  Text(0, 0, '1248'),
#  Text(0, 0, '1297'),
#  Text(0, 0, '1187'),
#  Text(0, 0, '1402'),
#  Text(0, 0, '1235'),
#  Text(0, 0, '1253'),
#  Text(0, 0, '1041'),
#  Text(0, 0, '1093'),
#  Text(0, 0, '1162'),
#  Text(0, 0, '1231'),
#  Text(0, 0, '1287')]

# %% [markdown]
#  ## univariant but continusous

# %%
sns.boxplot(df_uber.distance)
# Out:
# <Axes: ylabel='distance'>

# %%
sns.boxplot(df_lyft.distance)
# Out:
# <Axes: ylabel='distance'>

# %%
sns.boxplot(df_lyft.price)
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(df_uber.price)
# Out:
# <Axes: ylabel='price'>
